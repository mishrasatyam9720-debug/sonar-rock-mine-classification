# %% [markdown]
# <a href="https://colab.research.google.com/github/mishrasatyam9720-debug/sonar-rock-mine-classification/blob/main/rock_vs_mine_by_sonar_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("/content/sonar data.csv", header=None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df[60].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 60
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1541/2439143421.py in <cell line: 0>()
# ----> 1 df[60].value_counts()
#
# ...

# %%
df.groupby(60).mean()

# %%
x=df.drop(columns=60,axis=1)
y=df[60]

# %%
print(x)
print(y)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,stratify=y,random_state=1)

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)

# %%
x_train_prediction=model.predict(x_train)
train_accuracy_value=accuracy_score(x_train_prediction,y_train)

# %%
print(train_accuracy_value)

# %%
x_test_prediction=model.predict(x_test)
test_accuracy_score=accuracy_score(x_test_prediction,y_test)

# %%
print(test_accuracy_score)

# %% [markdown]
# prediction system

# %%
input_for_prediction=[0.0200,0.0371,0.0428,0.0207,0.0954,0.0986,0.1539,0.1601,0.3109,0.2111,0.1609,0.1582,0.2238,0.0645,0.0660,0.2273,0.3100,0.2999,0.5078,0.4797,0.5783,0.5071,0.4328,0.5550,0.6711,0.6415,0.7104,0.8080,0.6791,0.3857,0.1307,0.2604,0.5121,0.7547,0.8537,0.8507,0.6692,0.6097,0.4943,0.2744,0.0510,0.2834,0.2825,0.4256,0.2641,0.1386,0.1051,0.1343,0.0383,0.0324,0.0232,0.0027,0.0065,0.0159,0.0072,0.0167,0.0180,0.0084,0.0090,0.0032]

input_as_numpy_array=np.asarray(input_for_prediction)
input_data_reshape=input_as_numpy_array.reshape(1,-1)
prediction=model.predict(input_data_reshape)
print(prediction)
if ( prediction[0]=="R"):
  print(" it's expected as rock ")
else :
  print(" it's expected as mine ")
